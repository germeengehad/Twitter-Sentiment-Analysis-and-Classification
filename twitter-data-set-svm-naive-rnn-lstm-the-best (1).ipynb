# %% [markdown]
# # Import the libraries

# %%
import os
import zipfile
import pandas as pd
import spacy
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# !pip install contractions
import contractions
import re
import string
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from IPython.display import display, HTML
import warnings
import re
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
import nltk
nltk.download('punkt')
nlp = spacy.load("en_core_web_sm")
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import nltk
nltk.download('wordnet')
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (13 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-05-27 23:01:06.045709: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-27 23:01:06.045832: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-27 23:01:06.171615: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# #Prepare The Notbook

# %%
np.random.seed(500)

# %%
# Ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Import the data

# %%
os.environ['KAGGLE_USERNAME'] = "germeengehad"
os.environ['KAGGLE_KEY'] = "5f74e91f4236f3c4a3b265fe7c4c3a4a"

# %%
# !kaggle datasets download -d jp797498e/twitter-entity-sentiment-analysis
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.14 / client 1.6.12)
# Dataset URL: https://www.kaggle.com/datasets/jp797498e/twitter-entity-sentiment-analysis
# License(s): CC0-1.0
# Downloading twitter-entity-sentiment-analysis.zip to /kaggle/working
#   0%|                                               | 0.00/1.99M [00:00<?, ?B/s]
# 100%|███████████████████████████████████████| 1.99M/1.99M [00:00<00:00, 171MB/s]

# %%
#extract the zip fill of data
zip_ref = zipfile.ZipFile('/kaggle/working/twitter-entity-sentiment-analysis.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# # Load Data

# %%
# Load the dataset
training = pd.read_csv("/content/twitter_training.csv", encoding='latin-1', header=None)
validation = pd.read_csv("/content/twitter_validation.csv", encoding='latin-1', header=None)

# %%
# concatenate data
df = pd.concat([training, validation], ignore_index=False)
df.head()
# Out:
#       0            1         2  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                    3
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
df.columns=['id','information','labels','text']
df.head()
# Out:
#      id  information    labels  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 text
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75682 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           75682 non-null  int64
#  1   information  75682 non-null  object
#  2   labels       75682 non-null  object
#  3   text         74996 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.9+ MB

# %% [markdown]
# # EDA And Data preprossing

# %% [markdown]
# ## Check Missing Values

# %%
# check missing values
print(df.isnull().sum())
# Out:
# id               0
# information      0
# labels           0
# text           686
# dtype: int64

# %%
# remove missing values
df.dropna(inplace=True)
# check missing values
df.isnull().sum()
# Out:
# id             0
# information    0
# labels         0
# text           0
# dtype: int64

# %% [markdown]
# ## Check Duplicate Values

# %%
# check duplicate values
df.duplicated().sum()
# Out:
# 2857

# %%
# remove duplicate values
remove_duplicates = df.drop_duplicates()
df = remove_duplicates
# check duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Visualization

# %%
# Define custom colors
colors = ['red', 'green', 'blue', 'gray']

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(16, 6))

# Plotting pie chart for text distribution with custom colors
axs[0].pie(df['labels'].value_counts(), labels=df['labels'].unique(), autopct='%1.1f%%',
            startangle=90, wedgeprops={'linewidth': 0.5}, textprops={'fontsize': 12},
            explode=[0.1, 0.1, 0.1, 0.1], colors=colors, shadow=True)
axs[0].set_title('labels Distribution - Pie Chart')

# Plotting bar plot for text distribution
axs[1] = df['labels'].value_counts().plot(kind='bar', color=colors, ax=axs[1])
axs[1].set_title('labels Distribution - Bar Plot')
axs[1].set_xlabel('labels')
axs[1].set_ylabel('labels')
axs[1].tick_params(axis='x', rotation=45)
axs[1].grid(axis='y', linestyle='--', alpha=0.7)

# Add text on top of each bar in the bar plot
for p in axs[1].patches:
    axs[1].annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
# Create cross-tabulation table in plot
plt.figure(figsize=(10, 6))
count_table = pd.crosstab(index=df['information'], columns=df['labels'])
sns.heatmap(count_table, cmap='YlOrRd', annot=True, fmt='d',linewidths=0.5, linecolor='black')
plt.title('labels Distribution by information')
plt.xlabel('labels')
plt.ylabel('information')
plt.show()

# %%
# Display minimum and maximum values for each labels for each information
for labels in count_table.columns:
    min_branch = count_table[labels].idxmin()
    max_branch = count_table[labels].idxmax()
    min_val = count_table[labels].min()
    max_val = count_table[labels].max()
    print(f"Sentiment '{labels}':")
    print(f"  Minimum value '{min_val}' at Branch '{min_branch}'")
    print(f"  Maximum value '{max_val}' at Branch '{max_branch}'\n")
# Out:
# Sentiment 'Irrelevant':
#   Minimum value '23' at Branch 'TomClancysGhostRecon'
#   Maximum value '912' at Branch 'Battlefield'
#
# Sentiment 'Negative':
#   Minimum value '290' at Branch 'RedDeadRedemption(RDR)'
#   Maximum value '1672' at Branch 'MaddenNFL'
#
# Sentiment 'Neutral':
#   Minimum value '103' at Branch 'FIFA'
#   Maximum value '1210' at Branch 'Amazon'
#
# Sentiment 'Positive':
#   Minimum value '154' at Branch 'Facebook'
#   Maximum value '1393' at Branch 'AssassinsCreed'

# %%
#remove unessery coulmns
df.drop(columns=["id","information"],inplace=True)

# %%
df.head()
# Out:
#      labels                                               text
# 0  Positive  im getting on borderlands and i will murder yo...
# 1  Positive  I am coming to the borders and I will kill you...
# 2  Positive  im getting on borderlands and i will kill you ...
# 3  Positive  im coming on borderlands and i will murder you...
# 4  Positive  im getting on borderlands 2 and i will murder ...

# %%
# Use value_counts() to get counts of unique values in the 'labels' column
label_counts = df['labels'].value_counts()

# Print unique values and their counts
for label, count in label_counts.items():
    print(f"Label: {label}, Count: {count}")
# Out:
# Label: Negative, Count: 21790
# Label: Positive, Count: 19846
# Label: Neutral, Count: 17879
# Label: Irrelevant, Count: 12624

# %% [markdown]
# ## text preprossing

# %% [markdown]
# ## Prepare The Note Book

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np
nltk.download('wordnet', "/kaggle/working/nltk_data/")
nltk.download('omw-1.4', "/kaggle/working/nltk_data/")
! unzip /kaggle/working/nltk_data/corpora/wordnet.zip -d /kaggle/working/nltk_data/corpora
! unzip /kaggle/working/nltk_data/corpora/omw-1.4.zip -d /kaggle/working/nltk_data/corpora
nltk.data.path.append("/kaggle/working/nltk_data/")

# %%
import os
import nltk

# Set the NLTK_DATA environment variable
os.environ["NLTK_DATA"] = "/usr/local/share/nltk_data"  # Replace this with the appropriate directory

# Try downloading the WordNet corpus again
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /opt/conda/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('wordnet')
import nltk
nltk.download('wordnet', download_dir='/usr/local/share/nltk_data')
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /usr/local/share/nltk_data...
# True

# %% [markdown]
# ## Text Preprossing

# %%
import re
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

def process_text(text):
    text = re.sub(r'\s+', ' ', text, flags=re.I)  # Remove extra white space from text
    text = re.sub(r'\W', ' ', str(text))  # Remove all the special characters from text
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text)  # Remove all single characters from text
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove any character that isn't alphabetical
    text = text.lower()
    words = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    stop_words = set(stopwords.words("english"))
    Words = [word for word in words if word not in stop_words]
    Words = [word for word in Words if len(word) > 3]
    indices = np.unique(Words, return_index=True)[1]
    text = np.array(Words)[np.sort(indices)].tolist()
    return text

# %% [markdown]
# ## Splite The Data To X and Y

# %%
x = df.drop('labels', axis=1)
y = df.labels
texts = list(x['text'])
text = [process_text(text) for text in texts]

# Convert processed text to string format as the tokenizer expects strings
text = [" ".join(t) for t in text]

# %% [markdown]
# ## Over sampling

# %%
from imblearn.over_sampling import RandomOverSampler

# Apply over-sampling
ros = RandomOverSampler(random_state=42)
x, y = ros.fit_resample(np.array(text).reshape(-1, 1), y)
x = x.flatten()

# %% [markdown]
# ## Splitting The Data To Train And Test Sets

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Applying Text Embadding

# %%
max_vocab = 20000
tokenizer = Tokenizer(num_words=max_vocab)
tokenizer.fit_on_texts(X_train)
word_idx = tokenizer.word_index
v = len(word_idx)
print("the size of vocab =", v)

X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

maxlen = 100
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)
# Out:
# the size of vocab = 24873

# %%
y.value_counts()

# %% [markdown]
# # Build The Models

# %% [markdown]
# ### RNN Model

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense,Input,GlobalMaxPooling1D,Dropout,Bidirectional
from tensorflow.keras.models import Model

from keras import optimizers
import numpy as np
D=100
inputt=Input(shape=(maxlen,))

# %%
from tensorflow.keras.layers import Embedding, Dropout, Bidirectional, SimpleRNN
from tensorflow.keras.optimizers import Adam

learning_rate = 0.0001  # Set your desired learning rate here
x=Embedding(v+1,D)(inputt)
x = Dropout(0.7)(x)
x = Bidirectional(SimpleRNN(150))(x)
x = Dense(32, activation='relu')(x)
x = Dense(4, activation='softmax')(x)

model = Model(inputt, x)

# Define optimizer with specified learning rate
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
import tensorflow as tf

y_train_one_hot = tf.keras.utils.to_categorical(y_train_encoded)
y_test_one_hot = tf.keras.utils.to_categorical(y_test_encoded)
# Train the model with early stopping
history = model.fit(X_train, y_train_one_hot, epochs=17, validation_data=(X_test, y_test_one_hot))
# Out:
# Epoch 1/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 53s 20ms/step - accuracy: 0.2875 - loss: 1.3769 - val_accuracy: 0.4463 - val_loss: 1.2284
# Epoch 2/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.4970 - loss: 1.1468 - val_accuracy: 0.6871 - val_loss: 0.8298
# Epoch 3/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.6694 - loss: 0.8275 - val_accuracy: 0.7556 - val_loss: 0.6506
# Epoch 4/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.7379 - loss: 0.6663 - val_accuracy: 0.8077 - val_loss: 0.5277
# Epoch 5/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.7846 - loss: 0.5530 - val_accuracy: 0.8323 - val_loss: 0.4555
# Epoch 6/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.8130 - loss: 0.4832 - val_accuracy: 0.8414 - val_loss: 0.4255
# Epoch 7/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 45s 18ms/step - accuracy: 0.8349 - loss: 0.4305 - val_accuracy: 0.8573 - val_loss: 0.3818
# Epoch 8/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.8489 - loss: 0.3873 - val_accuracy: 0.8725 - val_loss: 0.3514
# Epoch 9/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 45s 18ms/step - accuracy: 0.8594 - loss: 0.3572 - val_accuracy: 0.8740 - val_loss: 0.3353
# Epoch 10/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.8735 - loss: 0.3247 - val_accuracy: 0.8817 - val_loss: 0.3202
# Epoch 11/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.8803 - loss: 0.3100 - val_accuracy: 0.8863 - val_loss: 0.3097
# Epoch 12/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 45s 18ms/step - accuracy: 0.8870 - loss: 0.2922 - val_accuracy: 0.8864 - val_loss: 0.3028
# Epoch 13/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.8904 - loss: 0.2790 - val_accuracy: 0.8901 - val_loss: 0.2935
# Epoch 14/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 45s 18ms/step - accuracy: 0.8977 - loss: 0.2604 - val_accuracy: 0.8881 - val_loss: 0.2915
# Epoch 15/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.8995 - loss: 0.2528 - val_accuracy: 0.8903 - val_loss: 0.2918
# Epoch 16/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 45s 18ms/step - accuracy: 0.9012 - loss: 0.2483 - val_accuracy: 0.8863 - val_loss: 0.3045
# Epoch 17/17
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 44s 18ms/step - accuracy: 0.9070 - loss: 0.2357 - val_accuracy: 0.8938 - val_loss: 0.2814

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### LSTM Model

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
learning_rate = 0.0001  # Set your desired learning rate here
x=Embedding(v+1,D)(inputt)
x = Dropout(0.7)(x)
x = Bidirectional(LSTM(150))(x)
x = Dense(32, activation='relu')(x)
x = Dense(4, activation='softmax')(x)

model = Model(inputt, x)

# Define optimizer with specified learning rate
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
import tensorflow as tf

y_train_one_hot = tf.keras.utils.to_categorical(y_train_encoded)
y_test_one_hot = tf.keras.utils.to_categorical(y_test_encoded)
# Train the model with early stopping
history = model.fit(X_train, y_train_one_hot, epochs=20, validation_data=(X_test, y_test_one_hot))
# Out:
# Epoch 1/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 36s 13ms/step - accuracy: 0.3371 - loss: 1.3336 - val_accuracy: 0.5903 - val_loss: 1.0054
# Epoch 2/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.6024 - loss: 0.9601 - val_accuracy: 0.6892 - val_loss: 0.7927
# Epoch 3/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.6872 - loss: 0.7846 - val_accuracy: 0.7513 - val_loss: 0.6668
# Epoch 4/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.7394 - loss: 0.6653 - val_accuracy: 0.7824 - val_loss: 0.5785
# Epoch 5/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.7750 - loss: 0.5796 - val_accuracy: 0.8060 - val_loss: 0.5220
# Epoch 6/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.7953 - loss: 0.5205 - val_accuracy: 0.8222 - val_loss: 0.4745
# Epoch 7/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8186 - loss: 0.4663 - val_accuracy: 0.8350 - val_loss: 0.4411
# Epoch 8/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8296 - loss: 0.4359 - val_accuracy: 0.8418 - val_loss: 0.4170
# Epoch 9/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8431 - loss: 0.4055 - val_accuracy: 0.8513 - val_loss: 0.3972
# Epoch 10/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8524 - loss: 0.3766 - val_accuracy: 0.8527 - val_loss: 0.3843
# Epoch 11/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8590 - loss: 0.3615 - val_accuracy: 0.8617 - val_loss: 0.3679
# Epoch 12/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8655 - loss: 0.3416 - val_accuracy: 0.8588 - val_loss: 0.3638
# Epoch 13/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8714 - loss: 0.3261 - val_accuracy: 0.8696 - val_loss: 0.3524
# Epoch 14/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8756 - loss: 0.3132 - val_accuracy: 0.8661 - val_loss: 0.3522
# Epoch 15/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8838 - loss: 0.2987 - val_accuracy: 0.8768 - val_loss: 0.3366
# Epoch 16/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8819 - loss: 0.2968 - val_accuracy: 0.8776 - val_loss: 0.3358
# Epoch 17/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8854 - loss: 0.2887 - val_accuracy: 0.8748 - val_loss: 0.3376
# Epoch 18/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8900 - loss: 0.2756 - val_accuracy: 0.8824 - val_loss: 0.3243
# Epoch 19/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8920 - loss: 0.2706 - val_accuracy: 0.8801 - val_loss: 0.3207
# Epoch 20/20
# 2452/2452 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8966 - loss: 0.2609 - val_accuracy: 0.8799 - val_loss: 0.3189

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### TfidfVectorizer

# %%
#Vectorize Data
def vectorize_data(text):
    # Join the tokenized text into strings
    text_data_strings = [" ".join(tokens) for tokens in text]
    # Initialize TfidfVectorizer
    tfidf_vectorizer = TfidfVectorizer()
    # Fit and transform the text data to generate TF-IDF vectors
    tfidf_vectors = tfidf_vectorizer.fit_transform(text)
    return tfidf_vectors, tfidf_vectorizer

# %% [markdown]
# ### SVM Model

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# %%
# Convert list of lists to list of strings
X_train = [' '.join(map(str, doc)) for doc in X_train]
X_test = [' '.join(map(str, doc)) for doc in X_test]

# Convert text data to TF-IDF features
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
# Train SVM classifier
SVM_classifier =SVC(random_state=42)
SVM_classifier.fit(X_train_tfidf, y_train)


# Predict on the testing data
y_pred = SVM_classifier.predict(X_test_tfidf)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)

# Predict on the testing data
y_pred_train = SVM_classifier.predict(X_train_tfidf)
accuracy = accuracy_score(y_train, y_pred_train)
print("train  Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.9264570904084443
# train  Accuracy: 0.9582759675692214

# %% [markdown]
# ### Naive Base Model

# %%
# Train Naive Bayes classifier
NB_classifier = naive_bayes.MultinomialNB()
NB_classifier.fit(X_train_tfidf, y_train)

# Predict on the testing data
y_pred = NB_classifier.predict(X_test_tfidf)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)

# Predict on the testing data
y_pred_train = NB_classifier.predict(X_train_tfidf)
accuracy = accuracy_score(y_train, y_pred_train)
print("train  Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.7761587884350619
# train  Accuracy: 0.8067028708377951
